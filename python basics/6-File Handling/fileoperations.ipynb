# %%
# read whole file

with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hey there, It's Starfire.
# Hope I complete my enitre course and get a certificate of completion.
# And an excellent job as well! ;)

# %%
with open('example.txt', 'r') as file:
    for line in file:
        print(line.strip()) #strip removes the extra new line character at the end of each line.
# Out:
# Hey there, It's Starfire.
# Hope I complete my enitre course and get a certificate of completion.
# And an excellent job as well! ;)
