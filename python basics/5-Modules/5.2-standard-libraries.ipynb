# %%
import array
arr= array.array('i',[2,5, 547, 5, 7])
print(arr)
# Out:
# array('i', [2, 5, 547, 5, 7])

# %%
import math
print(math.sqrt(25))    
print(math.pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple', 'banana', 'cherry']))
print(random.sample(range(1, 100), 5)) 
my_list = [1, 2, 3, 4, 5]
random.shuffle(my_list)
print(my_list)
# Out:
# 4
# apple
# [32, 90, 38, 83, 54]
# [2, 3, 4, 1, 5]

# %%
import os
print(os.getcwd())
# Out:
# /Users/shrutiagrawal/Documents/Udemy Gen AI Course/python basics/5-Modules

# %%
os.mkdir('new_directory')

# %%
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
# data serialization

import json

data = {'name':'star', 'age':25}

str_data = json.dumps(data)
print(str_data)
print(type(str_data))

parsed_data = json.loads(str_data)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "star", "age": 25}
# <class 'str'>
# {'name': 'star', 'age': 25}
# <class 'dict'>

# %%
#csv

import csv

with open('example.csv', mode = 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['star', 25])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['star', '25']

# %%
from datetime import timedelta, datetime

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-07-19 11:33:09.303013
# 2026-07-18 11:33:09.303013

# %%
import time

print(time.time())

time.sleep(2)

print(time.time())

timestamp = time.time()

print(time.ctime(timestamp))
# Out:
# 1784441254.9781
# 1784441256.9836621
# Sun Jul 19 11:37:36 2026

# %%
#regular expressions
import re

pattern = r'\d+'
text= "There are 123 apples and 456 oranges."
match = re.search(pattern , text)
print(match.group())
# Out:
# 123
