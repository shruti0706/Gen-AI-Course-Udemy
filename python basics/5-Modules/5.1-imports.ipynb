# %%
import math
math.sqrt(30)
# Out:
# 5.477225575051661

# %%
from math import sqrt, pi
print(sqrt(25))
# print(f"{sqrt(26):.2f}")
print(f"{pi:.2f}")
# Out:
# 5.0
# 3.14

# %%
import numpy as np
np.array([2,4,6,8,10])
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
from math import *
print(sqrt(16))
print(f"{pi:.2f}")
# Out:
# 4.0
# 3.14

# %%
from package.maths import addition

print(addition(5, 10))
# Out:
# 15

# %%
from package import maths
print(maths.addition(5, 10))
# Out:
# 15

# %%
from package.maths import *

print(subtraction(10, 5))
print(multiplication(5, 10))
print(division(10, 5))
# Out:
# 5
# 50
# 2.0

# %%
from package.subpackages.evenOdd import even_odd

print(even_odd(10))
print(even_odd(13))
# Out:
# Even
# Odd
