# %%
lst= []
type(lst)
# Out:
# list

# %%
lists= [1, 3.14, "hello", False, "abc"]
type(lists[3])
print(lists[1:4])
# Out:
# [3.14, 'hello', False]

# %%
lists= [1, 3.14, "hello", False, "abc"]
# lists[1:] = ["watermelon"] * 4
# lists[2:] = [2.5] * 3
print(lists[1:4])
print(lists[:4])

lists
# Out:
# [3.14, 'hello', False]
# [1, 3.14, 'hello', False]
# [1, 3.14, 'hello', False, 'abc']

# %%
fruits = ["apple", "guauva", "grapes", "pomo", "melon"]
fruits.append("orange")
fruits
# Out:
# ['apple', 'guauva', 'grapes', 'pomo', 'melon', 'orange']

# %%
fruits.insert(1, "banana")
fruits
# Out:
# ['apple', 'banana', 'guauve', 'grapes', 'pomo', 'melon', 'orange']

# %%
ls = [x**2 for x in range(10) if x%2 == 0]
ls
# Out:
# [0, 4, 16, 36, 64]

# %%
##nested list comprehension

ls1 = [1, 2, 4]
ls2 = ['a', 'b', 'c']

fls = [[i, j] for i in ls1 for j in ls2]
fls
# Out:
# [[1, 'a'],
#  [1, 'b'],
#  [1, 'c'],
#  [2, 'a'],
#  [2, 'b'],
#  [2, 'c'],
#  [4, 'a'],
#  [4, 'b'],
#  [4, 'c']]

# %%
lengths = [len(fruit) for fruit in fruits]
lengths
# Out:
# [5, 6, 6, 4, 5, 6]
