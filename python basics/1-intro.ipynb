# %%
1+1
# Out:
# 2

# %%
import sys
print(sys.executable)
# Out:
# /Users/shrutiagrawal/Documents/Udemy Gen AI Course/.venv/bin/python

# %%
age = 32
salary = 12000
percent = 87.6
print(percent)
print(salary)
percent = int(percent)
float(percent)
# Out:
# 87.6
# 12000
# 87.0

# %%
age = input("enter your age - ")
print(age)
# Out:
# 23.5

# %%
result = "hello" + "5"
result
result2 = "hello" + str(6)
result2
# Out:
# 'hello6'

# %%
28/5
# Out:
# 5.6

# %%
28//5  #floor division (removes decimal part and only shows integer value)
# Out:
# 5

# %%
x = False
y = True

res = x or y
res
# Out:
# True

# %%
res= x or y
res
# Out:
# True

# %%
x = True
not x
# Out:
# False

# %%
## if elif else

age = int(input("enter your age"))

if age >= 18:
    print("your are adult")
elif age<=0:
    print("Enter valid age")
else:
    print("minor!!")
# Out:
# minor!!

# %%
year = int(input("year"))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("leap year")
else:
    print("not a leap year")
# Out:
# leap year

# %%
num = [1,2,4]
# for i in num:
#     print(i)
for i in range(2, -1,-1):
    print(num[i])
# Out:
# 4
# 2
# 1

# %%
for i in range(1,10,3):
    print(i)
# Out:
# 1
# 4
# 7

# %%
count = 0

while count <= 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,4):
    for j in range(1,3):
        print(f"i: {i} and j : {j}")
# Out:
# i: 1 and j : 1
# i: 1 and j : 2
# i: 2 and j : 1
# i: 2 and j : 2
# i: 3 and j : 1
# i: 3 and j : 2
