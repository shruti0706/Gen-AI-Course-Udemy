# %% [markdown]
# #### Understanding Exceptions in Python
#  Exceptions are errors that occur during the execution of a program.
#  When an exception occurs, the normal flow of the program is interrupted,
#  and Python generates an error message. To handle exceptions gracefully and
#  prevent the program from crashing, we can use try-except blocks.

# %% [markdown]
# #### Common exceptions in Python include
# 1. `ZeroDivisionError`: Raised when dividing by zero.
# 2. `FileNotFoundError`: Raised when trying to access a file that does not exist.
# 3. `TypeError`: Raised when an operation or function is applied to an object of inappropriate type.
# 4. `ValueError`: Raised when a function receives an argument of the right type but an inappropriate value.

# %%
# exception try except block
try:
    a=b
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: name 'b' is not defined
